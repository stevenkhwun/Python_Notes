# %% [markdown]
# <font size = "6">Pandas equivalent of 10 useful SQL queries</font>
#
# ... or Pandas for SQL developers
#
# by DORIAN LAZAR
#
# The original notebook by the author can be accessed [here](https://www.kaggle.com/code/dorianlazar/pandas-equivalent-of-10-useful-sql-queries).
#
#
# Updated on 30 June 2024
# <hr>
#
# In case you don't know, pandas is a python library for data manipulation and analysis. In particular, it offers data structures and operations for manipulating numerical tables and time series. The name is derived from the term "panel data", an econometrics term for data sets that include observations over multiple time periods for the same individuals.[1](https://en.wikipedia.org/wiki/Pandas_(software)) Basically, it is a way of working with tables in python. In pandas tables of data are called `DataFrame`s.
#
# As the title suggests, in this article I'll show you the pandas equivalents of some of the most useful SQL queries. This can serve both as an introduction to pandas for those who already know SQL or as a cheat sheet of common pandas operations you may need.

# %% [markdown]
# <font size="5">Table of Contents</font>
# <div class="alert alert-block alert-info" style="margin-top: 20px">
#     <ul>
#         <li>
#             <a href="#SELECT">SELECT</a>
#             <ul>
#                 <li><a href="#SELECT-ALL">SELECT ALL</a></li>
#                 <li><a href="#SELECT-DISTINCT">SELECT DISTINCT</a></li>
#                 <li><a href="#SELECT-TOP-or-LIMIT">SELECT TOP or LIMIT</a></li>
#                 <li><a href="#MIN(),-MAX(),-COUNT(),-AVG(),-and-SUM()-functions">MIN(), MAX(), COUNT(), AVG(), and SUM() functions</a></li>
#             </ul>
#         </li>
#         <li>
#             <a href="#WHERE">WHERE</a>
#             <ul>
#                 <li><a href="#IS-NULL-or-IS-NOT-NULL">IS NULL or IS NOT NULL</a></li>
#                 <li><a href="#LIKE">LIKE</a></li>
#             </ul>
#         </li>
#         <li>
#             <a href="#ORDER-BY">ORDER BY</a>
#         </li>
#         <li>
#             <a href="#GROUP-BY">GROUP BY</a>
#         </li>
#         <li>
#             <a href="#HAVING">HAVING</a>
#         </li>
#         <li>
#             <a href="#INSERT">INSERT</a>
#         </li>
#         <li>
#             <a href="#DELETE">DELETE</a>
#         </li>
#         <li>
#             <a href="#ALTER">ALTER</a>
#             <ul>
#                 <li><a href="#ADD-column">ADD column</a></li>
#                 <li><a href="#DELETE-column">DELETE column</a></li>
#             </ul>
#         </li>
#         <li>
#             <a href="#UPDATE">UPDATE</a>
#         </li>
#         <li>
#             <a href="#JOIN">JOIN</a>
#             <ul>
#                 <li><a href="#INNER-JOIN">INNER JOIN</a></li>
#                 <li><a href="#OUTER-JOIN">OUTER JOIN</a></li>
#                 <li><a href="#LEFT-JOIN">LEFT JOIN</a></li>
#                 <li><a href="#RIGHT-JOIN">RIGHT JOIN</a></li>
#             </ul>
#         </li>
#     </ul>
# </div>
#
# <hr>

# %% [markdown]
# For the examples below I will use this dataset USvideos.csv which consists of data about trending YouTube videos in the US. It consists of 40949 rows with 16 columns: video_id,trending_date, title, channel_title, category_id, publish_time, tags, views, likes, dislikes, comment_count, thumbnail_link, comments_disabled, ratings_disabled, video_error_or_removed, description.

# %%
import numpy as np
import pandas as pd

# Reading the csv file into a DataFrame
df = pd.read_csv('data/USvideos.csv')
df
# Out:
#           video_id trending_date  \
# 0      2kyS6SvSYSE      17.14.11
# 1      1ZAPwfrtAFY      17.14.11
# 2      5qpjK5DgCt4      17.14.11
# 3      puqaWrEC7tY      17.14.11
# 4      d380meD0W0M      17.14.11
# ...            ...           ...
# 40944  BZt0qjTWNhw      18.14.06
# 40945  1h7KV2sjUWY      18.14.06
# 40946  D6Oy4LfoqsU      18.14.06
# 40947  oV0zkMe1K8s      18.14.06
# 40948  ooyjaVdt-jA      18.14.06
#
#                                                    title  \
# 0                     WE WANT TO TALK ABOUT OUR MARRIAGE
# 1      The Trump Presidency: Last Week Tonight with J...
# 2      Racist Superman | Rudy Mancuso, King Bach & Le...
# 3                       Nickelback Lyrics: Real or Fake?
# 4                               I Dare You: GOING BALD!?
# ...                                                  ...
# 40944                       The Cat Who Caught the Laser
# 40945                         True Facts : Ant Mutualism
# 40946  I GAVE SAFIYA NYGAARD A PERFECT HAIR MAKEOVER ...
# 40947                How Black Panther Should Have Ended
# 40948  Official Call of Duty®: Black Ops 4 — Multipla...
#
#                   channel_title  category_id              publish_time  \
# 0                  CaseyNeistat           22  2017-11-13T17:13:01.000Z
# 1               LastWeekTonight           24  2017-11-13T07:30:00.000Z
# 2                  Rudy Mancuso           23  2017-11-12T19:05:24.000Z
# 3         Good Mythical Morning           24  2017-11-13T11:00:04.000Z
# 4                      nigahiga           24  2017-11-12T18:01:41.000Z
# ...                         ...          ...                       ...
# 40944             AaronsAnimals           15  2018-05-18T13:00:04.000Z
# 40945                  zefrank1           22  2018-05-18T01:00:06.000Z
# 40946                Brad Mondo           24  2018-05-18T17:34:22.000Z
# 40947  How It Should Have Ended            1  2018-05-17T17:00:04.000Z
# 40948              Call of Duty           20  2018-05-17T17:09:38.000Z
#
#                                                     tags     views   likes  \
# 0                                        SHANtell martin    748374   57527
# 1      last week tonight trump presidency|"last week ...   2418783   97185
# 2      racist superman|"rudy"|"mancuso"|"king"|"bach"...   3191434  146033
# 3      rhett and link|"gmm"|"good mythical morning"|"...    343168   10172
# 4      ryan|"higa"|"higatv"|"nigahiga"|"i dare you"|"...   2095731  132235
# ...                                                  ...       ...     ...
# 40944  aarons animals|"aarons"|"animals"|"cat"|"cats"...   1685609   38160
# 40945                                             [none]   1064798   60008
# 40946  I gave safiya nygaard a perfect hair makeover ...   1066451   48068
# 40947  Black Panther|"HISHE"|"Marvel"|"Infinity War"|...   5660813  192957
# 40948      call of duty|"cod"|"activision"|"Black Ops 4"  10306119  357079
#
#        dislikes  comment_count  \
# 0          2966          15954
# 1          6146          12703
# 2          5339           8181
# 3           666           2146
# 4          1989          17518
# ...         ...            ...
# 40944      1385           2657
# 40945       382           3936
# 40946      1032           3992
# 40947      2846          13088
# 40948    212976         144795
#
#                                        thumbnail_link  comments_disabled  \
# 0      https://i.ytimg.com/vi/2kyS6SvSYSE/default.jpg              False
# 1      https://i.ytimg.com/vi/1ZAPwfrtAFY/default.jpg              False
# 2      https://i.ytimg.com/vi/5qpjK5DgCt4/default.jpg              False
# 3      https://i.ytimg.com/vi/puqaWrEC7tY/default.jpg              False
# 4      https://i.ytimg.com/vi/d380meD0W0M/default.jpg              False
# ...                                               ...                ...
# 40944  https://i.ytimg.com/vi/BZt0qjTWNhw/default.jpg              False
# 40945  https://i.ytimg.com/vi/1h7KV2sjUWY/default.jpg              False
# 40946  https://i.ytimg.com/vi/D6Oy4LfoqsU/default.jpg              False
# 40947  https://i.ytimg.com/vi/oV0zkMe1K8s/default.jpg              False
# 40948  https://i.ytimg.com/vi/ooyjaVdt-jA/default.jpg              False
#
#        ratings_disabled  video_error_or_removed  \
# 0                 False                   False
# 1                 False                   False
# 2                 False                   False
# 3                 False                   False
# 4                 False                   False
# ...                 ...                     ...
# 40944             False                   False
# 40945             False                   False
# 40946             False                   False
# 40947             False                   False
# 40948             False                   False
#
#                                              description
# 0      SHANTELL'S CHANNEL - https://www.youtube.com/s...
# 1      One year after the presidential election, John...
# 2      WATCH MY PREVIOUS VIDEO ▶ \n\nSUBSCRIBE ► http...
# 3      Today we find out if Link is a Nickelback amat...
# 4      I know it's been a while since we did this sho...
# ...                                                  ...
# 40944     The Cat Who Caught the Laser - Aaron's Animals
# 40945                                                NaN
# 40946  I had so much fun transforming Safiyas hair in...
# 40947  How Black Panther Should Have EndedWatch More ...
# 40948  Call of Duty: Black Ops 4 Multiplayer raises t...
#
# [40949 rows x 16 columns]

# %% [markdown]
# Pandas operations, by default, don't modify the data frame which you are working with; they just return other data frames which you need to assign to a variable if you want to save the changes. For most examples below we don't change our original data frame, we just show the returned result.

# %% [markdown]
# # SELECT

# %% [markdown]
# ## SELECT ALL
# ```SQL
# SELECT col1, col2, ... FROM table
# ```
#
# The SELECT statement is used to select columns of data from a table.
#
# To do the same thing in pandas we just have to use the array notation on the data frame and inside the square brackets pass a list with the column names you want to select.

# %%
df[['video_id', 'title']]
# Out:
#           video_id                                              title
# 0      2kyS6SvSYSE                 WE WANT TO TALK ABOUT OUR MARRIAGE
# 1      1ZAPwfrtAFY  The Trump Presidency: Last Week Tonight with J...
# 2      5qpjK5DgCt4  Racist Superman | Rudy Mancuso, King Bach & Le...
# 3      puqaWrEC7tY                   Nickelback Lyrics: Real or Fake?
# 4      d380meD0W0M                           I Dare You: GOING BALD!?
# ...            ...                                                ...
# 40944  BZt0qjTWNhw                       The Cat Who Caught the Laser
# 40945  1h7KV2sjUWY                         True Facts : Ant Mutualism
# 40946  D6Oy4LfoqsU  I GAVE SAFIYA NYGAARD A PERFECT HAIR MAKEOVER ...
# 40947  oV0zkMe1K8s                How Black Panther Should Have Ended
# 40948  ooyjaVdt-jA  Official Call of Duty®: Black Ops 4 — Multipla...
#
# [40949 rows x 2 columns]

# %% [markdown]
# The same thing can be made with the following syntax which makes easier to translate WHERE statements later:

# %%
df.loc[:, ['video_id', 'title']]
# Out:
#           video_id                                              title
# 0      2kyS6SvSYSE                 WE WANT TO TALK ABOUT OUR MARRIAGE
# 1      1ZAPwfrtAFY  The Trump Presidency: Last Week Tonight with J...
# 2      5qpjK5DgCt4  Racist Superman | Rudy Mancuso, King Bach & Le...
# 3      puqaWrEC7tY                   Nickelback Lyrics: Real or Fake?
# 4      d380meD0W0M                           I Dare You: GOING BALD!?
# ...            ...                                                ...
# 40944  BZt0qjTWNhw                       The Cat Who Caught the Laser
# 40945  1h7KV2sjUWY                         True Facts : Ant Mutualism
# 40946  D6Oy4LfoqsU  I GAVE SAFIYA NYGAARD A PERFECT HAIR MAKEOVER ...
# 40947  oV0zkMe1K8s                How Black Panther Should Have Ended
# 40948  ooyjaVdt-jA  Official Call of Duty®: Black Ops 4 — Multipla...
#
# [40949 rows x 2 columns]

# %% [markdown]
# ## SELECT DISTINCT
#
# ```SQL
# SELECT DISTINCT col1, col2, ... FROM table
# ```
#
# The SELECT DISTINCT statement returns only unique rows form a table.
#
# In a data frame there may be duplicate values. If you want to get only distinct rows (remove duplicates) it is as simple as calling the `.drop_duplicates()` method. Judging based on this method's name you may think that it removes duplicate rows from your initial data frame, but what it actually does is to return a new data frame with duplicate rows removed.

# %%
df.loc[:, ['channel_title']].drop_duplicates()
# Out:
#                   channel_title
# 0                  CaseyNeistat
# 1               LastWeekTonight
# 2                  Rudy Mancuso
# 3         Good Mythical Morning
# 4                      nigahiga
# ...                         ...
# 40366                      HALO
# 40475            Ben Kronengold
# 40488           All Def Digital
# 40540  How It Should Have Ended
# 40554     Ubisoft North America
#
# [2207 rows x 1 columns]

# %% [markdown]
# ## SELECT TOP or LIMIT
#
# ```SQL
# SELECT TOP number col1, col2 FROM table
# ```
# or
# ```SQL
# SELECT col1, col2, ... FROM table LIMIT number
# ```
#
# The TOP or LIMIT keyword in SQL is used to limit the number of returned rows from the top of the table.
#
# In pandas this is very easy to do with `.head(number)` method. Pandas also has the `.tail(number)` method for showing the rows from the end of data frame.

# %%
df.loc[:, ['video_id', 'title']].head(5)
# Out:
#       video_id                                              title
# 0  2kyS6SvSYSE                 WE WANT TO TALK ABOUT OUR MARRIAGE
# 1  1ZAPwfrtAFY  The Trump Presidency: Last Week Tonight with J...
# 2  5qpjK5DgCt4  Racist Superman | Rudy Mancuso, King Bach & Le...
# 3  puqaWrEC7tY                   Nickelback Lyrics: Real or Fake?
# 4  d380meD0W0M                           I Dare You: GOING BALD!?

# %%
df.loc[:, ['video_id', 'title']].tail(5)
# Out:
#           video_id                                              title
# 40944  BZt0qjTWNhw                       The Cat Who Caught the Laser
# 40945  1h7KV2sjUWY                         True Facts : Ant Mutualism
# 40946  D6Oy4LfoqsU  I GAVE SAFIYA NYGAARD A PERFECT HAIR MAKEOVER ...
# 40947  oV0zkMe1K8s                How Black Panther Should Have Ended
# 40948  ooyjaVdt-jA  Official Call of Duty®: Black Ops 4 — Multipla...

# %% [markdown]
# ## MIN(), MAX(), COUNT(), AVG(), and SUM() functions
#
# SQL's MIN(), MAX(), COUNT(), AVG(), and SUM() functions are pretty straightforward to translate to pandas:

# %% [markdown]
# ```SQL
# SELECT MIN(col) FROM table
# ```

# %%
df.loc[:, ['views']].min()
# Out:
# views    549
# dtype: int64

# %% [markdown]
# ```SQL
# SELECT MAX(col) FROM table
# ```

# %%
df.loc[:, ['views']].max()
# Out:
# views    225211923
# dtype: int64

# %% [markdown]
# ```SQL
# SELECT COUNT(col) FROM table
# ```

# %%
df.loc[:, ['views']].count()
# Out:
# views    40949
# dtype: int64

# %% [markdown]
# ```SQL
# SELECT AVG(col) FROM table
# ```

# %%
df.loc[:, ['views']].mean()
# Out:
# views    2.360785e+06
# dtype: float64

# %% [markdown]
# ```SQL
# SELECT SUM(col) FROM table
# ```

# %%
df.loc[:, ['views']].sum()
# Out:
# views    96671770152
# dtype: int64

# %% [markdown]
# Now, what if we want to do something like this:
# ```SQL
# SELECT MAX(likes), MIN(dislikes) FROM table
# ```
# We need to do this in more steps:

# %%
new_df = df.loc[:, ['likes']].max().rename({'likes': 'MAX(likes)'})
new_df['MIN(dislikes)'] = df.loc[:, ['dislikes']].min().values[0]
new_df
# Out:
# MAX(likes)       5613827
# MIN(dislikes)          0
# dtype: int64

# %% [markdown]
# # WHERE
#
# ```SQL
# SELECT col1, col2, ... FROM table WHERE condition
# ```
#
# The WHERE clause is used to extract only the rows that fulfill a specified condition.
#
# Recall the syntax we used so far for selecting columns:
#
# ```Python
# df.loc[:, ['col1', 'col2']]
# ```
# Inside the square brackets of `.loc` there is place for two parameters; so far we only used the second one which is used to specify what columns you want to select. Guess for what is the first parameter? Is for selecting rows. Pandas data frames expect a list of row indices or boolean flags based on which it extracts the rows we need. So far we used only the `:` symbol which means "return all rows". If we want to extract only rows with indices from 50 to 80 we can use `50:80` in that place. For extracting rows based on some condition, most often we will pass there an array of boolean flags returned by some (vectorized) boolean operation. The rows on positions where we will have False will not be included in the result, only those rows with True on their positions will be returned.
#
# Using equality and inequality operators `==`, `<`, `<=`, `>`, `>=`, `!=` in conditions is straightforward. For example, to return only rows that have number of likes >= 1000000 we can use:

# %%
df.loc[df['likes'] >= 1000000, ['video_id', 'title']]
# Out:
#           video_id                                              title
# 70     2Vv-BfVoq4g        Ed Sheeran - Perfect (Official Music Video)
# 336    2Vv-BfVoq4g        Ed Sheeran - Perfect (Official Music Video)
# 574    2Vv-BfVoq4g        Ed Sheeran - Perfect (Official Music Video)
# 801    TyHvyGVs42U          Luis Fonsi, Demi Lovato - Échame La Culpa
# 1005   TyHvyGVs42U          Luis Fonsi, Demi Lovato - Échame La Culpa
# ...            ...                                                ...
# 40823  VY1eFxgRR-k                         Selena Gomez - Back To You
# 40824  J2HytHu5VBI                                        we broke up
# 40855  D_6QmL6rExk  BTS (방탄소년단) 'FAKE LOVE' Official MV (Extended ...
# 40869  xTlNMmZKwpA  Cardi B, Bad Bunny & J Balvin - I Like It [Off...
# 40896  nQySbNGu4g0  [CHOREOGRAPHY] BTS (방탄소년단) 'FAKE LOVE' Dance P...
#
# [369 rows x 2 columns]

# %% [markdown]
# Note that the reason for which we could do what we did above (`df['likes'] >= 1000000`) is that pandas has overwritten the default behavior for `>=` operator so that it applies the operator element-wise and returns an array of booleans of the shape that we need (number of rows).
#
# But the operators `and`, `or`, `not` don't work like that. So, we will use `&` instead of `and`, `|` instead of `or`, `~` instead of `not`.

# %%
df.loc[(df['likes'] >= 1000000) & (df['dislikes'] <= 5000), ['video_id', 'title']].drop_duplicates()
# Out:
#           video_id                                              title
# 1278   ixxR3ZoqnF0  BTS (방탄소년단) 'MIC Drop (Steve Aoki Remix)' Offi...
# 14755  J41qe-TM1DY                    JONGHYUN 종현 '빛이 나 (Shinin’)' MV
# 20823  Vm4Xn5vjqRA        CRISTIANO RONALDO E FRED, O GRANDE ENCONTRO
# 35156  2tDKp41nrw8          BTS (방탄소년단) 'FAKE LOVE' Official Teaser 2
# 37987  nQySbNGu4g0  [CHOREOGRAPHY] BTS (방탄소년단) 'FAKE LOVE' Dance P...

# %% [markdown]
# ## IS NULL or IS NOT NULL
#
# ```SQL
# SELECT col1, col2, ... FROM table WHERE colN IS NOT NULL
# ```
#
# In SQL you can use IS NULL or IS NOT NULL to get rows that contain/don't contain null values.
#
# How to check for null values in pandas?
#
# We will use `isnull(array-like)` function from pandas package to do that. Note that this is not a method of data frame objects, don't use `df.isnull(...)`; instead do `pd.isnull(df['column']`). So be careful.

# %%
df.loc[pd.isnull(df['description']), ['video_id', 'title', 'description']].drop_duplicates()
# Out:
#           video_id                                              title  \
# 42     NZFhMSgbKKM  Dennis Smith Jr. and LeBron James go back and ...
# 47     sbcbvuitiTc  Stephon Marbury and Jimmer Fredette fight in C...
# 175    4d07RXYLsJE                Sphaera - demonstrating interaction
# 446    upEIZAihcwo  Devin Booker has words with Lakers assistant J...
# 632    U5sCjnezw4o  Jaylen Brown delivers emotional press conferen...
# ...            ...                                                ...
# 32150  zxwfDlhJIpw                 kanye west / charlamagne interview
# 33775  Hzk1bM2vVFU                    True Facts : Carnivorous Plants
# 34151  vjSohj-Iclc                           Getting some air, Atlas?
# 35988  1h7KV2sjUWY                         True Facts : Ant Mutualism
# 36961  H08xgoXkpa8  Snoop Dogg Weighs In On Kanye's Controversial ...
#
#       description
# 42            NaN
# 47            NaN
# 175           NaN
# 446           NaN
# 632           NaN
# ...           ...
# 32150         NaN
# 33775         NaN
# 34151         NaN
# 35988         NaN
# 36961         NaN
#
# [105 rows x 3 columns]

# %% [markdown]
# The example below returns all rows where the description is not null.

# %%
df.loc[~pd.isnull(df['description']), ['video_id', 'title', 'description']].drop_duplicates()
# Out:
#           video_id                                              title  \
# 0      2kyS6SvSYSE                 WE WANT TO TALK ABOUT OUR MARRIAGE
# 1      1ZAPwfrtAFY  The Trump Presidency: Last Week Tonight with J...
# 2      5qpjK5DgCt4  Racist Superman | Rudy Mancuso, King Bach & Le...
# 3      puqaWrEC7tY                   Nickelback Lyrics: Real or Fake?
# 4      d380meD0W0M                           I Dare You: GOING BALD!?
# ...            ...                                                ...
# 40762  6h8QgZF5Qu4  Drop the Mic w/ Ashton Kutcher & Sean Diddy Combs
# 40764  mpnshdmtE2Y  Carla Makes BA Smashburgers | From the Test Ki...
# 40766  yz7Xq3T0YPs  Katherine Langford on 13 Reasons Why, Australi...
# 40793  SWVtV59mczk         Battlefield 5 Official Multiplayer Trailer
# 40846  Wz_YwUpNOcw                                     Wouldn't Leave
#
#                                              description
# 0      SHANTELL'S CHANNEL - https://www.youtube.com/s...
# 1      One year after the presidential election, John...
# 2      WATCH MY PREVIOUS VIDEO ▶ \n\nSUBSCRIBE ► http...
# 3      Today we find out if Link is a Nickelback amat...
# 4      I know it's been a while since we did this sho...
# ...                                                  ...
# 40762  James Corden and Ashton Kutcher square off in ...
# 40764  Ground chuck is a great all-purpose, buy-it-an...
# 40766  Katherine talks about learning accents, growin...
# 40793  Battlefield™ V launches worldwide on October 1...
# 40846  Provided to YouTube by Universal Music GroupWo...
#
# [7034 rows x 3 columns]

# %% [markdown]
# ## LIKE
#
# ```SQL
# SELECT col1, col2, ... FROM table WHERE colN LIKE pattern
# ```
#
# The LIKE keyword can be used in a WHERE clause to test if a column matches a pattern.
#
# In pandas we can use python's native `re` module for regular expressions to accomplish the same thing, or even more as the python's `re` module allows for a richer set of patterns to be tested rather than SQL's LIKE.
#
# We will create a function `like(x, pattern)` where `x` is an array-like object and `pattern` is a string containing the pattern which we want to test for. This function will first compile the `pattern` into a regular expression object, then we can use the `.fullmatch(val)` method to test the `val`'s value against our `pattern`. In order to apply this test to each element in our `x` vector we will use numpy's `vectorize(func)` function to create a vector equivalent for our operation of regex matching. Finally we apply this vectorized function to our `x` input vector. Then all we need to do is to pass `like(df['column'], pattern)` as pirst parameter in `.loc[]`.

# %%
import re

def like(x, pattern):
    r = re.compile(pattern)
    vlike = np.vectorize(lambda val: bool(r.fullmatch(val)))
    return vlike(x)

# %% [markdown]
# As an example the below code returns all videos that contains the word 'math' in their description.

# %%
df_notnull = df.loc[~pd.isnull(df['description']), :]
df_notnull.loc[like(df_notnull['description'], '.* math .*'), ['video_id', 'title']].drop_duplicates()
# Out:
#           video_id                                              title
# 1905   WKcYTvyoidw  Parenting Habits That Could Keep Children From...
# 26016  DjjBg8hTaPo                   How Much Food Is There On Earth?

# %% [markdown]
# # ORDER BY
#
# ```SQL
# SELECT col1, col2, ... FROM table ORDER BY col1, col2 ASC|DESC
# ```
#
# This SQL keyword is used to sort the results in ascending or descending order.
#
# It is straightforward to translate this to pandas, you just call the `.sort_values(by=['col1', ...], ascending=True/False)` method on a dataframe.

# %%
df.loc[df['likes'] >= 1000000, ['video_id', 'title']].sort_values(by=['title'], ascending=True).drop_duplicates()
# Out:
#           video_id                                              title
# 31025  ffxKSjUwKdU               Ariana Grande - No Tears Left To Cry
# 28156  kX0vO4vlJuU  BTS (방탄소년단) 'Euphoria : Theme of LOVE YOURSELF...
# 36816  7C2z4GqqS5E                BTS (방탄소년단) 'FAKE LOVE' Official MV
# 38352  D_6QmL6rExk  BTS (방탄소년단) 'FAKE LOVE' Official MV (Extended ...
# 35370  2tDKp41nrw8          BTS (방탄소년단) 'FAKE LOVE' Official Teaser 2
# 2626   kTlv5_Bs8aw  BTS (방탄소년단) 'MIC Drop (Steve Aoki Remix)' Offi...
# 1752   ixxR3ZoqnF0  BTS (방탄소년단) 'MIC Drop (Steve Aoki Remix)' Offi...
# 34562  p8npDG2ulKQ  BTS (방탄소년단) LOVE YOURSELF 轉 Tear 'Singularity'...
# 33541  zEf423kYfqk  Becky G, Natti Natasha - Sin Pijama (Official ...
# 11585  LsoLEjrDogU  Bruno Mars - Finesse (Remix) [Feat. Cardi B] [...
# 20823  Vm4Xn5vjqRA        CRISTIANO RONALDO E FRED, O GRANDE ENCONTRO
# 39211  xTlNMmZKwpA  Cardi B, Bad Bunny & J Balvin - I Like It [Off...
# 37123  VYOjWnS4cMY  Childish Gambino - This Is America (Official V...
# 4476   SM1w9PEQOE8                  Demi Lovato - Tell Me You Love Me
# 12994  Mgfe5tIwOj0            Dua Lipa - IDGAF (Official Music Video)
# 34330  iWZmdoY1aTE              Ed Sheeran - Happier (Official Video)
# 70     2Vv-BfVoq4g        Ed Sheeran - Perfect (Official Music Video)
# 7767   eiDiKwbGfIY  Ed Sheeran - Perfect Symphony (with Andrea Boc...
# 20159  wfWIs2gFTAM                      Eminem - River ft. Ed Sheeran
# 25514  sS0LCjOiIhc                                      GOT7 Look M/V
# 14755  J41qe-TM1DY                    JONGHYUN 종현 '빛이 나 (Shinin’)' MV
# 17063  _5d-sQ7Fh5M                                LOGAN PAUL IS BACK!
# 6978   khPLWaBioOs  Logan Paul - SANTA DISS TRACK (Official Music ...
# 2365   TyHvyGVs42U          Luis Fonsi, Demi Lovato - Échame La Culpa
# 38765  aJOTlE1K90k              Maroon 5 - Girls Like You ft. Cardi B
# 24559  QwievZ1Tx-8  Marvel Studios' Avengers: Infinity War - Offic...
# 4043   6ZfuNTqbHE8  Marvel Studios' Avengers: Infinity War Officia...
# 14951  VRJmcxCrAOA             Real Life Trick Shots 2 | Dude Perfect
# 15925  J_CFBjAyPWE                       Red Velvet 레드벨벳 'Bad Boy' MV
# 40194  VY1eFxgRR-k                         Selena Gomez - Back To You
# 32030  36tggrpRoTI                         Shawn Mendes - In My Blood
# 10862  QwZT7T-TXT0                                          So Sorry.
# 14201  oWjxSkJpxFU                         Suicide: Be Here Tomorrow.
# 29243  i0p1bmr0EmE                            TWICE What is Love? M/V
# 26339  tCXGJQYZ9JA                            Taylor Swift - Delicate
# 12992  dfnCAmr569k     Taylor Swift - End Game ft. Ed Sheeran, Future
# 31313  M4ZoCHID9GI     The Weeknd - Call Out My Name (Official Video)
# 31584  u9Mv98Gr5pY                      VENOM - Official Trailer (HD)
# 6181   FlsCjmMhFmw  YouTube Rewind: The Shape of 2017 | #YouTubeRe...
# 29827  J-dv_DcDD_A                     ZAYN - Let Me (Official Video)
# 40072  nQySbNGu4g0  [CHOREOGRAPHY] BTS (방탄소년단) 'FAKE LOVE' Dance P...
# 24739  8O_MwlZ2dEg                               j-hope 'Airplane' MV
# 21813  OK3GJ0WIQ8s                         j-hope 'Daydream (백일몽)' MV
# 39993  J2HytHu5VBI                                        we broke up

# %% [markdown]
# # GROUP BY
#
# ```SQL
# SELECT col1, col2, ... FROM table GROUP BY colN
# ```
#
# The GROUP BY statement groups rows that have the same value for a specific column. It is often used with aggregate functions (MIN, MAX, COUNT, SUM, AVG).
#
# In pandas it is as simple as calling the `.groupby(['col1', ...])` method, followed by a call to one of `.min()`, `.max()`, `.count()`, `.sum`, `.mean()` methods.

# %%
df.loc[:, ['channel_title', 'views', 'likes', 'dislikes']].groupby(['channel_title']).sum()
# Out:
#                              views     likes  dislikes
# channel_title
# 12 News                     177970       352        90
# 1MILLION Dance Studio     20959169   1399898     15030
# 1theK (원더케이)              57375949   3663362     63329
# 20th Century Fox        1082872611  24419452    488761
# 2CELLOS                     432186     22900       245
# ...                            ...       ...       ...
# ワーナー ブラザース 公式チャンネル         7389323    154962      6128
# 圧倒的不審者の極み!                11417717    157447     12315
# 杰威爾音樂 JVR Music          400530463   3400678    229439
# 郭韋辰                          26964        99         2
# 영국남자 Korean Englishman     5963784    147154      2579
#
# [2207 rows x 3 columns]

# %% [markdown]
# # HAVING
#
# ```SQL
# SELECT col1, col2, ... FROM table GROUP BY colN HAVING condition
# ```
#
# The HAVING keyword is used to filter the results based on group-level conditions.
#
# In pandas we have the `.filter(func)` method that can be called after a `groupby()` call. We need to pass to this method a function that takes a data frame of a group as a parameter and returns a boolean value that decides whether this group is included in the results or not.
#
# But if we want to do more things at once in pandas, e.g. apply aggregate functions on columns and filter results based on group-level conditions, we need to do this in more steps. Whereas in SQL we could have done this in only one query. In the example below we want to group by _channel_title_, allow only channels that have at least 100 different videos in the table, and apply average function on _views_, _likes_, and _dislikes_.
#
# In SQL this would be:
#
# ```SQL
# SELECT channel_title, AVG(views), AVG(likes), AVG(dislikes)
# FROM videos_table
# GROUP BY channel_title
# HAVING COUNT(video_id) > 100;
# ```

# %%
g = df.groupby(['channel_title'])
g = g.filter(lambda x: x['video_id'].count() > 100)
g = g.loc[:, ['channel_title', 'views', 'likes', 'dislikes']].groupby(['channel_title']).mean()
g
# Out:
#                               views          likes     dislikes
# channel_title
# 20th Century Fox       8.021279e+06  180884.829630  3620.451852
# ABC News               4.540516e+05    3627.186992  2276.097561
# AsapSCIENCE            5.162413e+06   86787.370968  5019.612903
# Binging with Babish    1.074592e+06   33679.839286   820.625000
# Bon Appétit            8.502353e+05   22298.470199   712.410596
# ...                             ...            ...          ...
# WWE                    2.789609e+06   42768.108280  2400.515924
# Warner Bros. Pictures  4.434285e+06   39682.760000  5070.613333
# Washington Post        1.604080e+06   13914.634783  7038.773913
# You Suck At Cooking    7.727879e+05   35612.719626  1015.813084
# jacksfilms             1.348708e+06   94536.297297  2718.081081
#
# [69 rows x 3 columns]

# %% [markdown]
# # INSERT
#
# ```SQL
# INSERT INTO table (column1, column2, ...) VALUES (value1, value2, ...)
# ```
#
# This SQL statement is used to insert new rows in the table.
#
#
# In pandas we can use the `concat(DataFrame1, DataFrame2)` function to append a new data frame at the end of an existing one. We will use `ignore_index=True` in order to continue indexing from the last row in the old data frame.

# %%
new_row = pd.DataFrame({'video_id': ['EkZGBdY0vlg'],
                        'channel_title': ['Professor Leonard'],
                        'title': ['Calculus 3 Lecture 13.3: Partial Derivatives']})

df = pd.concat([df, new_row], ignore_index=True)
df
# Out:
#           video_id trending_date  \
# 0      2kyS6SvSYSE      17.14.11
# 1      1ZAPwfrtAFY      17.14.11
# 2      5qpjK5DgCt4      17.14.11
# 3      puqaWrEC7tY      17.14.11
# 4      d380meD0W0M      17.14.11
# ...            ...           ...
# 40945  1h7KV2sjUWY      18.14.06
# 40946  D6Oy4LfoqsU      18.14.06
# 40947  oV0zkMe1K8s      18.14.06
# 40948  ooyjaVdt-jA      18.14.06
# 40949  EkZGBdY0vlg           NaN
#
#                                                    title  \
# 0                     WE WANT TO TALK ABOUT OUR MARRIAGE
# 1      The Trump Presidency: Last Week Tonight with J...
# 2      Racist Superman | Rudy Mancuso, King Bach & Le...
# 3                       Nickelback Lyrics: Real or Fake?
# 4                               I Dare You: GOING BALD!?
# ...                                                  ...
# 40945                         True Facts : Ant Mutualism
# 40946  I GAVE SAFIYA NYGAARD A PERFECT HAIR MAKEOVER ...
# 40947                How Black Panther Should Have Ended
# 40948  Official Call of Duty®: Black Ops 4 — Multipla...
# 40949       Calculus 3 Lecture 13.3: Partial Derivatives
#
#                   channel_title  category_id              publish_time  \
# 0                  CaseyNeistat         22.0  2017-11-13T17:13:01.000Z
# 1               LastWeekTonight         24.0  2017-11-13T07:30:00.000Z
# 2                  Rudy Mancuso         23.0  2017-11-12T19:05:24.000Z
# 3         Good Mythical Morning         24.0  2017-11-13T11:00:04.000Z
# 4                      nigahiga         24.0  2017-11-12T18:01:41.000Z
# ...                         ...          ...                       ...
# 40945                  zefrank1         22.0  2018-05-18T01:00:06.000Z
# 40946                Brad Mondo         24.0  2018-05-18T17:34:22.000Z
# 40947  How It Should Have Ended          1.0  2018-05-17T17:00:04.000Z
# 40948              Call of Duty         20.0  2018-05-17T17:09:38.000Z
# 40949         Professor Leonard          NaN                       NaN
#
#                                                     tags       views  \
# 0                                        SHANtell martin    748374.0
# 1      last week tonight trump presidency|"last week ...   2418783.0
# 2      racist superman|"rudy"|"mancuso"|"king"|"bach"...   3191434.0
# 3      rhett and link|"gmm"|"good mythical morning"|"...    343168.0
# 4      ryan|"higa"|"higatv"|"nigahiga"|"i dare you"|"...   2095731.0
# ...                                                  ...         ...
# 40945                                             [none]   1064798.0
# 40946  I gave safiya nygaard a perfect hair makeover ...   1066451.0
# 40947  Black Panther|"HISHE"|"Marvel"|"Infinity War"|...   5660813.0
# 40948      call of duty|"cod"|"activision"|"Black Ops 4"  10306119.0
# 40949                                                NaN         NaN
#
#           likes  dislikes  comment_count  \
# 0       57527.0    2966.0        15954.0
# 1       97185.0    6146.0        12703.0
# 2      146033.0    5339.0         8181.0
# 3       10172.0     666.0         2146.0
# 4      132235.0    1989.0        17518.0
# ...         ...       ...            ...
# 40945   60008.0     382.0         3936.0
# 40946   48068.0    1032.0         3992.0
# 40947  192957.0    2846.0        13088.0
# 40948  357079.0  212976.0       144795.0
# 40949       NaN       NaN            NaN
#
#                                        thumbnail_link comments_disabled  \
# 0      https://i.ytimg.com/vi/2kyS6SvSYSE/default.jpg             False
# 1      https://i.ytimg.com/vi/1ZAPwfrtAFY/default.jpg             False
# 2      https://i.ytimg.com/vi/5qpjK5DgCt4/default.jpg             False
# 3      https://i.ytimg.com/vi/puqaWrEC7tY/default.jpg             False
# 4      https://i.ytimg.com/vi/d380meD0W0M/default.jpg             False
# ...                                               ...               ...
# 40945  https://i.ytimg.com/vi/1h7KV2sjUWY/default.jpg             False
# 40946  https://i.ytimg.com/vi/D6Oy4LfoqsU/default.jpg             False
# 40947  https://i.ytimg.com/vi/oV0zkMe1K8s/default.jpg             False
# 40948  https://i.ytimg.com/vi/ooyjaVdt-jA/default.jpg             False
# 40949                                             NaN               NaN
#
#       ratings_disabled video_error_or_removed  \
# 0                False                  False
# 1                False                  False
# 2                False                  False
# 3                False                  False
# 4                False                  False
# ...                ...                    ...
# 40945            False                  False
# 40946            False                  False
# 40947            False                  False
# 40948            False                  False
# 40949              NaN                    NaN
#
#                                              description
# 0      SHANTELL'S CHANNEL - https://www.youtube.com/s...
# 1      One year after the presidential election, John...
# 2      WATCH MY PREVIOUS VIDEO ▶ \n\nSUBSCRIBE ► http...
# 3      Today we find out if Link is a Nickelback amat...
# 4      I know it's been a while since we did this sho...
# ...                                                  ...
# 40945                                                NaN
# 40946  I had so much fun transforming Safiyas hair in...
# 40947  How Black Panther Should Have EndedWatch More ...
# 40948  Call of Duty: Black Ops 4 Multiplayer raises t...
# 40949                                                NaN
#
# [40950 rows x 16 columns]

# %% [markdown]
# # DELETE
#
# ```SQL
# DELETE FROM table WHERE condition
# ```
#
# DELETE statement is used to delete existing rows from a table based on some condition.
#
# In pandas we can use `.drop()` method to romove the rows whose indices we pass in. Unlike other methods this one doesn't accept boolean arrays as input. So we must convert our condition's output to indices. We can do that with `np.where()` function.
#
# In the example below we deleted all the rows where `channel_title != '3Blue1Brown'`.

# %%
df.drop(np.where(df['channel_title'] != '3Blue1Brown')[0])
# Out:
#           video_id trending_date  \
# 15541  spUNpyF58BY      18.01.02
# 23992  bcPTiiiYDs8      18.16.03
# 24206  bcPTiiiYDs8      18.17.03
# 24420  bcPTiiiYDs8      18.18.03
# 24633  bcPTiiiYDs8      18.19.03
# 24853  bcPTiiiYDs8      18.20.03
# 25070  bcPTiiiYDs8      18.21.03
# 25281  bcPTiiiYDs8      18.22.03
# 25494  bcPTiiiYDs8      18.23.03
# 26630  b7FxPsqfkOY      18.29.03
# 26851  b7FxPsqfkOY      18.30.03
# 27065  b7FxPsqfkOY      18.31.03
# 27274  b7FxPsqfkOY      18.01.04
# 27490  b7FxPsqfkOY      18.02.04
#
#                                                    title channel_title  \
# 15541  But what is the Fourier Transform?  A visual i...   3Blue1Brown
# 23992                      How pi was almost 6.283185...   3Blue1Brown
# 24206                      How pi was almost 6.283185...   3Blue1Brown
# 24420                      How pi was almost 6.283185...   3Blue1Brown
# 24633                      How pi was almost 6.283185...   3Blue1Brown
# 24853                      How pi was almost 6.283185...   3Blue1Brown
# 25070                      How pi was almost 6.283185...   3Blue1Brown
# 25281                      How pi was almost 6.283185...   3Blue1Brown
# 25494                      How pi was almost 6.283185...   3Blue1Brown
# 26630              How to solve 2D equations using color   3Blue1Brown
# 26851              How to solve 2D equations using color   3Blue1Brown
# 27065              How to solve 2D equations using color   3Blue1Brown
# 27274              How to solve 2D equations using color   3Blue1Brown
# 27490              How to solve 2D equations using color   3Blue1Brown
#
#        category_id              publish_time  \
# 15541         27.0  2018-01-26T18:47:48.000Z
# 23992         27.0  2018-03-14T13:05:32.000Z
# 24206         27.0  2018-03-14T13:05:32.000Z
# 24420         27.0  2018-03-14T13:05:32.000Z
# 24633         27.0  2018-03-14T13:05:32.000Z
# 24853         27.0  2018-03-14T13:05:32.000Z
# 25070         27.0  2018-03-14T13:05:32.000Z
# 25281         27.0  2018-03-14T13:05:32.000Z
# 25494         27.0  2018-03-14T13:05:32.000Z
# 26630         27.0  2018-03-24T14:42:51.000Z
# 26851         27.0  2018-03-24T14:42:51.000Z
# 27065         27.0  2018-03-24T14:42:51.000Z
# 27274         27.0  2018-03-24T14:42:51.000Z
# 27490         27.0  2018-03-24T14:42:51.000Z
#
#                                                     tags     views    likes  \
# 15541  Mathematics|"three blue one brown"|"3 blue 1 b...  298666.0  21524.0
# 23992  Mathematics|"three blue one brown"|"3 blue 1 b...  236393.0   9791.0
# 24206  Mathematics|"three blue one brown"|"3 blue 1 b...  269878.0  10425.0
# 24420  Mathematics|"three blue one brown"|"3 blue 1 b...  280015.0  10766.0
# 24633  Mathematics|"three blue one brown"|"3 blue 1 b...  287291.0  11000.0
# 24853  Mathematics|"three blue one brown"|"3 blue 1 b...  292273.0  11150.0
# 25070  Mathematics|"three blue one brown"|"3 blue 1 b...  296379.0  11255.0
# 25281  Mathematics|"three blue one brown"|"3 blue 1 b...  299420.0  11332.0
# 25494  Mathematics|"three blue one brown"|"3 blue 1 b...  302153.0  11390.0
# 26630  Mathematics|"three blue one brown"|"3 blue 1 b...  229838.0  11873.0
# 26851  Mathematics|"three blue one brown"|"3 blue 1 b...  235802.0  12060.0
# 27065  Mathematics|"three blue one brown"|"3 blue 1 b...  240059.0  12187.0
# 27274  Mathematics|"three blue one brown"|"3 blue 1 b...  244314.0  12314.0
# 27490  Mathematics|"three blue one brown"|"3 blue 1 b...  248330.0  12453.0
#
#        dislikes  comment_count  \
# 15541      90.0         1912.0
# 23992      88.0          828.0
# 24206     110.0          882.0
# 24420     118.0          891.0
# 24633     121.0          901.0
# 24853     122.0          909.0
# 25070     123.0          916.0
# 25281     124.0          917.0
# 25494     124.0          925.0
# 26630      84.0          940.0
# 26851      85.0          986.0
# 27065      86.0         1003.0
# 27274      89.0         1018.0
# 27490      89.0         1044.0
#
#                                        thumbnail_link comments_disabled  \
# 15541  https://i.ytimg.com/vi/spUNpyF58BY/default.jpg             False
# 23992  https://i.ytimg.com/vi/bcPTiiiYDs8/default.jpg             False
# 24206  https://i.ytimg.com/vi/bcPTiiiYDs8/default.jpg             False
# 24420  https://i.ytimg.com/vi/bcPTiiiYDs8/default.jpg             False
# 24633  https://i.ytimg.com/vi/bcPTiiiYDs8/default.jpg             False
# 24853  https://i.ytimg.com/vi/bcPTiiiYDs8/default.jpg             False
# 25070  https://i.ytimg.com/vi/bcPTiiiYDs8/default.jpg             False
# 25281  https://i.ytimg.com/vi/bcPTiiiYDs8/default.jpg             False
# 25494  https://i.ytimg.com/vi/bcPTiiiYDs8/default.jpg             False
# 26630  https://i.ytimg.com/vi/b7FxPsqfkOY/default.jpg             False
# 26851  https://i.ytimg.com/vi/b7FxPsqfkOY/default.jpg             False
# 27065  https://i.ytimg.com/vi/b7FxPsqfkOY/default.jpg             False
# 27274  https://i.ytimg.com/vi/b7FxPsqfkOY/default.jpg             False
# 27490  https://i.ytimg.com/vi/b7FxPsqfkOY/default.jpg             False
#
#       ratings_disabled video_error_or_removed  \
# 15541            False                  False
# 23992            False                  False
# 24206            False                  False
# 24420            False                  False
# 24633            False                  False
# 24853            False                  False
# 25070            False                  False
# 25281            False                  False
# 25494            False                  False
# 26630            False                  False
# 26851            False                  False
# 27065            False                  False
# 27274            False                  False
# 27490            False                  False
#
#                                              description
# 15541  An animated introduction to the Fourier Transf...
# 23992  Happy pi day!  Did you know that in some of hi...
# 24206  Happy pi day!  Did you know that in some of hi...
# 24420  Happy pi day!  Did you know that in some of hi...
# 24633  Happy pi day!  Did you know that in some of hi...
# 24853  Happy pi day!  Did you know that in some of hi...
# 25070  Happy pi day!  Did you know that in some of hi...
# 25281  Happy pi day!  Did you know that in some of hi...
# 25494  Happy pi day!  Did you know that in some of hi...
# 26630  A story of winding numbers and composition.\nB...
# 26851  A story of winding numbers and composition.\nB...
# 27065  A story of winding numbers and composition.\nB...
# 27274  A story of winding numbers and composition.\nB...
# 27490  A story of winding numbers and composition.\nB...

# %%
# Alternatively
# df.drop(np.where(~(df['channel_title'] == '3Blue1Brown'))[0])

# %% [markdown]
# # ALTER

# %% [markdown]
# ## ADD column
#
# ```SQL
# ALTER TABLE table ADD column
# ```
#
# This SQL statement adds new columns.
#
# In pandas we can do this by: `df['new_column'] = array-like`.
#
# Below we add a new column 'like_ratio':

# %%
df['like_ratio'] = df['likes'] / (df['likes'] + df['dislikes'])
df
# Out:
#           video_id trending_date  \
# 0      2kyS6SvSYSE      17.14.11
# 1      1ZAPwfrtAFY      17.14.11
# 2      5qpjK5DgCt4      17.14.11
# 3      puqaWrEC7tY      17.14.11
# 4      d380meD0W0M      17.14.11
# ...            ...           ...
# 40945  1h7KV2sjUWY      18.14.06
# 40946  D6Oy4LfoqsU      18.14.06
# 40947  oV0zkMe1K8s      18.14.06
# 40948  ooyjaVdt-jA      18.14.06
# 40949  EkZGBdY0vlg           NaN
#
#                                                    title  \
# 0                     WE WANT TO TALK ABOUT OUR MARRIAGE
# 1      The Trump Presidency: Last Week Tonight with J...
# 2      Racist Superman | Rudy Mancuso, King Bach & Le...
# 3                       Nickelback Lyrics: Real or Fake?
# 4                               I Dare You: GOING BALD!?
# ...                                                  ...
# 40945                         True Facts : Ant Mutualism
# 40946  I GAVE SAFIYA NYGAARD A PERFECT HAIR MAKEOVER ...
# 40947                How Black Panther Should Have Ended
# 40948  Official Call of Duty®: Black Ops 4 — Multipla...
# 40949       Calculus 3 Lecture 13.3: Partial Derivatives
#
#                   channel_title  category_id              publish_time  \
# 0                  CaseyNeistat         22.0  2017-11-13T17:13:01.000Z
# 1               LastWeekTonight         24.0  2017-11-13T07:30:00.000Z
# 2                  Rudy Mancuso         23.0  2017-11-12T19:05:24.000Z
# 3         Good Mythical Morning         24.0  2017-11-13T11:00:04.000Z
# 4                      nigahiga         24.0  2017-11-12T18:01:41.000Z
# ...                         ...          ...                       ...
# 40945                  zefrank1         22.0  2018-05-18T01:00:06.000Z
# 40946                Brad Mondo         24.0  2018-05-18T17:34:22.000Z
# 40947  How It Should Have Ended          1.0  2018-05-17T17:00:04.000Z
# 40948              Call of Duty         20.0  2018-05-17T17:09:38.000Z
# 40949         Professor Leonard          NaN                       NaN
#
#                                                     tags       views  \
# 0                                        SHANtell martin    748374.0
# 1      last week tonight trump presidency|"last week ...   2418783.0
# 2      racist superman|"rudy"|"mancuso"|"king"|"bach"...   3191434.0
# 3      rhett and link|"gmm"|"good mythical morning"|"...    343168.0
# 4      ryan|"higa"|"higatv"|"nigahiga"|"i dare you"|"...   2095731.0
# ...                                                  ...         ...
# 40945                                             [none]   1064798.0
# 40946  I gave safiya nygaard a perfect hair makeover ...   1066451.0
# 40947  Black Panther|"HISHE"|"Marvel"|"Infinity War"|...   5660813.0
# 40948      call of duty|"cod"|"activision"|"Black Ops 4"  10306119.0
# 40949                                                NaN         NaN
#
#           likes  dislikes  comment_count  \
# 0       57527.0    2966.0        15954.0
# 1       97185.0    6146.0        12703.0
# 2      146033.0    5339.0         8181.0
# 3       10172.0     666.0         2146.0
# 4      132235.0    1989.0        17518.0
# ...         ...       ...            ...
# 40945   60008.0     382.0         3936.0
# 40946   48068.0    1032.0         3992.0
# 40947  192957.0    2846.0        13088.0
# 40948  357079.0  212976.0       144795.0
# 40949       NaN       NaN            NaN
#
#                                        thumbnail_link comments_disabled  \
# 0      https://i.ytimg.com/vi/2kyS6SvSYSE/default.jpg             False
# 1      https://i.ytimg.com/vi/1ZAPwfrtAFY/default.jpg             False
# 2      https://i.ytimg.com/vi/5qpjK5DgCt4/default.jpg             False
# 3      https://i.ytimg.com/vi/puqaWrEC7tY/default.jpg             False
# 4      https://i.ytimg.com/vi/d380meD0W0M/default.jpg             False
# ...                                               ...               ...
# 40945  https://i.ytimg.com/vi/1h7KV2sjUWY/default.jpg             False
# 40946  https://i.ytimg.com/vi/D6Oy4LfoqsU/default.jpg             False
# 40947  https://i.ytimg.com/vi/oV0zkMe1K8s/default.jpg             False
# 40948  https://i.ytimg.com/vi/ooyjaVdt-jA/default.jpg             False
# 40949                                             NaN               NaN
#
#       ratings_disabled video_error_or_removed  \
# 0                False                  False
# 1                False                  False
# 2                False                  False
# 3                False                  False
# 4                False                  False
# ...                ...                    ...
# 40945            False                  False
# 40946            False                  False
# 40947            False                  False
# 40948            False                  False
# 40949              NaN                    NaN
#
#                                              description  like_ratio
# 0      SHANTELL'S CHANNEL - https://www.youtube.com/s...    0.950970
# 1      One year after the presidential election, John...    0.940521
# 2      WATCH MY PREVIOUS VIDEO ▶ \n\nSUBSCRIBE ► http...    0.964729
# 3      Today we find out if Link is a Nickelback amat...    0.938550
# 4      I know it's been a while since we did this sho...    0.985181
# ...                                                  ...         ...
# 40945                                                NaN    0.993674
# 40946  I had so much fun transforming Safiyas hair in...    0.978982
# 40947  How Black Panther Should Have EndedWatch More ...    0.985465
# 40948  Call of Duty: Black Ops 4 Multiplayer raises t...    0.626394
# 40949                                                NaN         NaN
#
# [40950 rows x 17 columns]

# %% [markdown]
# ## DELETE column
#
# ```SQL
# ALTER TABLE table DROP COLUMN column
# ```
#
# This SQL statement deletes a column.
#
# `del df['column']` is how we do this in pandas.

# %%
del df['comments_disabled']
df
# Out:
#           video_id trending_date  \
# 0      2kyS6SvSYSE      17.14.11
# 1      1ZAPwfrtAFY      17.14.11
# 2      5qpjK5DgCt4      17.14.11
# 3      puqaWrEC7tY      17.14.11
# 4      d380meD0W0M      17.14.11
# ...            ...           ...
# 40945  1h7KV2sjUWY      18.14.06
# 40946  D6Oy4LfoqsU      18.14.06
# 40947  oV0zkMe1K8s      18.14.06
# 40948  ooyjaVdt-jA      18.14.06
# 40949  EkZGBdY0vlg           NaN
#
#                                                    title  \
# 0                     WE WANT TO TALK ABOUT OUR MARRIAGE
# 1      The Trump Presidency: Last Week Tonight with J...
# 2      Racist Superman | Rudy Mancuso, King Bach & Le...
# 3                       Nickelback Lyrics: Real or Fake?
# 4                               I Dare You: GOING BALD!?
# ...                                                  ...
# 40945                         True Facts : Ant Mutualism
# 40946  I GAVE SAFIYA NYGAARD A PERFECT HAIR MAKEOVER ...
# 40947                How Black Panther Should Have Ended
# 40948  Official Call of Duty®: Black Ops 4 — Multipla...
# 40949       Calculus 3 Lecture 13.3: Partial Derivatives
#
#                   channel_title  category_id              publish_time  \
# 0                  CaseyNeistat         22.0  2017-11-13T17:13:01.000Z
# 1               LastWeekTonight         24.0  2017-11-13T07:30:00.000Z
# 2                  Rudy Mancuso         23.0  2017-11-12T19:05:24.000Z
# 3         Good Mythical Morning         24.0  2017-11-13T11:00:04.000Z
# 4                      nigahiga         24.0  2017-11-12T18:01:41.000Z
# ...                         ...          ...                       ...
# 40945                  zefrank1         22.0  2018-05-18T01:00:06.000Z
# 40946                Brad Mondo         24.0  2018-05-18T17:34:22.000Z
# 40947  How It Should Have Ended          1.0  2018-05-17T17:00:04.000Z
# 40948              Call of Duty         20.0  2018-05-17T17:09:38.000Z
# 40949         Professor Leonard          NaN                       NaN
#
#                                                     tags       views  \
# 0                                        SHANtell martin    748374.0
# 1      last week tonight trump presidency|"last week ...   2418783.0
# 2      racist superman|"rudy"|"mancuso"|"king"|"bach"...   3191434.0
# 3      rhett and link|"gmm"|"good mythical morning"|"...    343168.0
# 4      ryan|"higa"|"higatv"|"nigahiga"|"i dare you"|"...   2095731.0
# ...                                                  ...         ...
# 40945                                             [none]   1064798.0
# 40946  I gave safiya nygaard a perfect hair makeover ...   1066451.0
# 40947  Black Panther|"HISHE"|"Marvel"|"Infinity War"|...   5660813.0
# 40948      call of duty|"cod"|"activision"|"Black Ops 4"  10306119.0
# 40949                                                NaN         NaN
#
#           likes  dislikes  comment_count  \
# 0       57527.0    2966.0        15954.0
# 1       97185.0    6146.0        12703.0
# 2      146033.0    5339.0         8181.0
# 3       10172.0     666.0         2146.0
# 4      132235.0    1989.0        17518.0
# ...         ...       ...            ...
# 40945   60008.0     382.0         3936.0
# 40946   48068.0    1032.0         3992.0
# 40947  192957.0    2846.0        13088.0
# 40948  357079.0  212976.0       144795.0
# 40949       NaN       NaN            NaN
#
#                                        thumbnail_link ratings_disabled  \
# 0      https://i.ytimg.com/vi/2kyS6SvSYSE/default.jpg            False
# 1      https://i.ytimg.com/vi/1ZAPwfrtAFY/default.jpg            False
# 2      https://i.ytimg.com/vi/5qpjK5DgCt4/default.jpg            False
# 3      https://i.ytimg.com/vi/puqaWrEC7tY/default.jpg            False
# 4      https://i.ytimg.com/vi/d380meD0W0M/default.jpg            False
# ...                                               ...              ...
# 40945  https://i.ytimg.com/vi/1h7KV2sjUWY/default.jpg            False
# 40946  https://i.ytimg.com/vi/D6Oy4LfoqsU/default.jpg            False
# 40947  https://i.ytimg.com/vi/oV0zkMe1K8s/default.jpg            False
# 40948  https://i.ytimg.com/vi/ooyjaVdt-jA/default.jpg            False
# 40949                                             NaN              NaN
#
#       video_error_or_removed  \
# 0                      False
# 1                      False
# 2                      False
# 3                      False
# 4                      False
# ...                      ...
# 40945                  False
# 40946                  False
# 40947                  False
# 40948                  False
# 40949                    NaN
#
#                                              description  like_ratio
# 0      SHANTELL'S CHANNEL - https://www.youtube.com/s...    0.950970
# 1      One year after the presidential election, John...    0.940521
# 2      WATCH MY PREVIOUS VIDEO ▶ \n\nSUBSCRIBE ► http...    0.964729
# 3      Today we find out if Link is a Nickelback amat...    0.938550
# 4      I know it's been a while since we did this sho...    0.985181
# ...                                                  ...         ...
# 40945                                                NaN    0.993674
# 40946  I had so much fun transforming Safiyas hair in...    0.978982
# 40947  How Black Panther Should Have EndedWatch More ...    0.985465
# 40948  Call of Duty: Black Ops 4 Multiplayer raises t...    0.626394
# 40949                                                NaN         NaN
#
# [40950 rows x 16 columns]

# %% [markdown]
# # UPDATE
#
# ```SQL
# UPDATE table_name
# SET column1 = value1, column2 = value2, ...
# WHERE condition;
# ```
#
# The UPDATE statement is used to change values in our table based on some condition.
#
# For doing this in python we can use numpy's `where()` function. We also saw this function a few lines above when we used it to convert boolean array to indices array. That is what this function does when given just one parameter. This function can receive 3 arrays of the same size as parameters, first one being a boolean array. Let's call them `c`, `x`, `y`. It returns an array of the same size filled with elements from `x` and `y` choosen in this way: if `c[i]` is true choose `x[i]` else choose `y[i]`.
#
# To modify a data frame column we can do: `df['column'] = np.where(condition, new_values, df['column'])`.
#
# In the example below we increase the number of likes by 100 where `channel_title == 'Veritasium'`.
#
# This is how the data looks before:

# %%
df.loc[df['channel_title'] == 'Veritasium', ['title', 'likes']]
# Out:
#                                    title    likes
# 1425     Your Amazing Molecular Machines  20617.0
# 1655     Your Amazing Molecular Machines  26534.0
# 1900     Your Amazing Molecular Machines  28693.0
# 2106     Your Amazing Molecular Machines  30270.0
# 2316     Your Amazing Molecular Machines  31134.0
# 2538     Your Amazing Molecular Machines  31793.0
# 2757     Your Amazing Molecular Machines  32341.0
# 2988     Your Amazing Molecular Machines  32735.0
# 6051  This Particle Breaks Time Symmetry  43101.0
# 6274  This Particle Breaks Time Symmetry  46459.0
# 6510  This Particle Breaks Time Symmetry  47972.0
# 6721  This Particle Breaks Time Symmetry  49445.0
# 6958  This Particle Breaks Time Symmetry  50496.0
# 7195  This Particle Breaks Time Symmetry  51253.0

# %%
df['likes'] = np.where(df['channel_title'] == 'Veritasium', df['likes']+100, df['likes'])

# %% [markdown]
# And after:

# %%
df.loc[df['channel_title'] == 'Veritasium', ['title', 'likes']]
# Out:
#                                    title    likes
# 1425     Your Amazing Molecular Machines  20717.0
# 1655     Your Amazing Molecular Machines  26634.0
# 1900     Your Amazing Molecular Machines  28793.0
# 2106     Your Amazing Molecular Machines  30370.0
# 2316     Your Amazing Molecular Machines  31234.0
# 2538     Your Amazing Molecular Machines  31893.0
# 2757     Your Amazing Molecular Machines  32441.0
# 2988     Your Amazing Molecular Machines  32835.0
# 6051  This Particle Breaks Time Symmetry  43201.0
# 6274  This Particle Breaks Time Symmetry  46559.0
# 6510  This Particle Breaks Time Symmetry  48072.0
# 6721  This Particle Breaks Time Symmetry  49545.0
# 6958  This Particle Breaks Time Symmetry  50596.0
# 7195  This Particle Breaks Time Symmetry  51353.0

# %% [markdown]
# # JOIN
#
# A JOIN clause is used to combine rows from two or more tables based on a related column between them.
#
# In order to show examples of joins I need at least two tables, so I will split the data frame used so far into two smaller tables.

# %%
df_titles = df.loc[:, ['video_id', 'title']].drop_duplicates()
df_titles
# Out:
#           video_id                                              title
# 0      2kyS6SvSYSE                 WE WANT TO TALK ABOUT OUR MARRIAGE
# 1      1ZAPwfrtAFY  The Trump Presidency: Last Week Tonight with J...
# 2      5qpjK5DgCt4  Racist Superman | Rudy Mancuso, King Bach & Le...
# 3      puqaWrEC7tY                   Nickelback Lyrics: Real or Fake?
# 4      d380meD0W0M                           I Dare You: GOING BALD!?
# ...            ...                                                ...
# 40761  JGm9Y_hFqNk  First Take reacts: Kyrie Irving says contract ...
# 40762  6h8QgZF5Qu4  Drop the Mic w/ Ashton Kutcher & Sean Diddy Combs
# 40764  mpnshdmtE2Y  Carla Makes BA Smashburgers | From the Test Ki...
# 40766  yz7Xq3T0YPs  Katherine Langford on 13 Reasons Why, Australi...
# 40949  EkZGBdY0vlg       Calculus 3 Lecture 13.3: Partial Derivatives
#
# [6464 rows x 2 columns]

# %%
df_stats = df.loc[:, ['video_id', 'views', 'likes', 'dislikes']].groupby('video_id').max()
df_stats = df_stats.reset_index()
df_stats
# Out:
#          video_id      views     likes  dislikes
# 0     -0CMnp02rNY   800359.0    9773.0     332.0
# 1     -0NYY8cqdiQ   563746.0    4429.0      54.0
# 2     -1Hm41N0dUs  2058516.0   41248.0     580.0
# 3     -1yT-K3c6YI   231341.0    7734.0     212.0
# 4     -2RVw2_QyxQ    71089.0     460.0      27.0
# ...           ...        ...       ...       ...
# 6347  zwEn-ambXLw   241668.0    8478.0     144.0
# 6348  zxUwbflE1SY   225280.0    5770.0     150.0
# 6349  zxwfDlhJIpw  8442986.0  166520.0   19462.0
# 6350  zy0b9e40tK8   378750.0    5642.0     146.0
# 6351  zzQsGL_F9_c   199041.0    1415.0     121.0
#
# [6352 rows x 4 columns]

# %% [markdown]
# Doing joins in pandas is straightforward: it has a `.join()` method that we can use like this: `df1.join(df2.set_index('key_column'), on='key_column')`
#
# There are more types of joins: inner, full, left, and right joins.
# * INNER JOIN: returns rows that have matching values in both tables
# * FULL (OUTER) JOIN: returns rows that have matching values in any of the tables
# * LEFT JOIN: returns all rows from the left table, and the matched rows from the right one
# * RIGHT JOIN: returns all rows from the right table, and the matched rows from the left one
#
# To specify which type of join you want in pandas you can use the `how` parameter in `.join()` method. This parameter can be one of: 'inner', 'outer', 'left', 'right'.
#
# Below are examples of these types of joins of the two data frames above on 'video_id' column.

# %% [markdown]
# ## INNER JOIN
#
# ```SQL
# SELECT column_name(s)
# FROM table1
# INNER JOIN table2
# ON table1.column_name = table2.column_name;
# ```

# %%
df_titles.join(df_stats.set_index('video_id'), on='video_id', how='inner')
# Out:
#           video_id                                              title  \
# 0      2kyS6SvSYSE                 WE WANT TO TALK ABOUT OUR MARRIAGE
# 1      1ZAPwfrtAFY  The Trump Presidency: Last Week Tonight with J...
# 2      5qpjK5DgCt4  Racist Superman | Rudy Mancuso, King Bach & Le...
# 3      puqaWrEC7tY                   Nickelback Lyrics: Real or Fake?
# 4      d380meD0W0M                           I Dare You: GOING BALD!?
# ...            ...                                                ...
# 40761  JGm9Y_hFqNk  First Take reacts: Kyrie Irving says contract ...
# 40762  6h8QgZF5Qu4  Drop the Mic w/ Ashton Kutcher & Sean Diddy Combs
# 40764  mpnshdmtE2Y  Carla Makes BA Smashburgers | From the Test Ki...
# 40766  yz7Xq3T0YPs  Katherine Langford on 13 Reasons Why, Australi...
# 40949  EkZGBdY0vlg       Calculus 3 Lecture 13.3: Partial Derivatives
#
#            views     likes  dislikes
# 0      2564903.0   96321.0    7972.0
# 1      6109402.0  151250.0   11508.0
# 2      5315471.0  187303.0    7278.0
# 3       913268.0   16729.0    1386.0
# 4      2819118.0  153395.0    2416.0
# ...          ...       ...       ...
# 40761   812832.0    7701.0     320.0
# 40762   864189.0   18811.0     399.0
# 40764   540149.0   14206.0     693.0
# 40766   296295.0    8157.0     294.0
# 40949        NaN       NaN       NaN
#
# [6464 rows x 5 columns]

# %% [markdown]
# ## OUTER JOIN
#
# ```SQL
# SELECT column_name(s)
# FROM table1
# FULL OUTER JOIN table2
# ON table1.column_name = table2.column_name
# WHERE condition;
# ```

# %%
df_titles.join(df_stats.set_index('video_id'), on='video_id', how='outer')
# Out:
#           video_id                                              title  \
# 39169  -0CMnp02rNY  Mindy Kaling's Daughter Had the Perfect Reacti...
# 15457  -0NYY8cqdiQ  Megan Mullally Didn't Notice the Interesting P...
# 31553  -1Hm41N0dUs  Cast of Avengers: Infinity War Draws Their Cha...
# 3019   -1yT-K3c6YI  YOUTUBER QUIZ + TRUTH OR DARE W/ THE MERRELL T...
# 90     -2RVw2_QyxQ                     2017 Champions Showdown: Day 3
# ...            ...                                                ...
# 26002  zwEn-ambXLw  This Is Me - Cover by Shoshana Bean Featuring ...
# 246    zxUwbflE1SY  100 People Hold Their Breath for as Long as Th...
# 32150  zxwfDlhJIpw                 kanye west / charlamagne interview
# 144    zy0b9e40tK8             Dark | Official Trailer [HD] | Netflix
# 16360  zzQsGL_F9_c                     Budweiser | Beer Country | :60
#
#            views     likes  dislikes
# 39169   800359.0    9773.0     332.0
# 15457   563746.0    4429.0      54.0
# 31553  2058516.0   41248.0     580.0
# 3019    231341.0    7734.0     212.0
# 90       71089.0     460.0      27.0
# ...          ...       ...       ...
# 26002   241668.0    8478.0     144.0
# 246     225280.0    5770.0     150.0
# 32150  8442986.0  166520.0   19462.0
# 144     378750.0    5642.0     146.0
# 16360   199041.0    1415.0     121.0
#
# [6464 rows x 5 columns]

# %% [markdown]
# ## LEFT JOIN
#
# ```SQL
# SELECT column_name(s)
# FROM table1
# LEFT JOIN table2
# ON table1.column_name = table2.column_name;
# ```

# %%
df_titles.join(df_stats.set_index('video_id'), on='video_id', how='left')
# Out:
#           video_id                                              title  \
# 0      2kyS6SvSYSE                 WE WANT TO TALK ABOUT OUR MARRIAGE
# 1      1ZAPwfrtAFY  The Trump Presidency: Last Week Tonight with J...
# 2      5qpjK5DgCt4  Racist Superman | Rudy Mancuso, King Bach & Le...
# 3      puqaWrEC7tY                   Nickelback Lyrics: Real or Fake?
# 4      d380meD0W0M                           I Dare You: GOING BALD!?
# ...            ...                                                ...
# 40761  JGm9Y_hFqNk  First Take reacts: Kyrie Irving says contract ...
# 40762  6h8QgZF5Qu4  Drop the Mic w/ Ashton Kutcher & Sean Diddy Combs
# 40764  mpnshdmtE2Y  Carla Makes BA Smashburgers | From the Test Ki...
# 40766  yz7Xq3T0YPs  Katherine Langford on 13 Reasons Why, Australi...
# 40949  EkZGBdY0vlg       Calculus 3 Lecture 13.3: Partial Derivatives
#
#            views     likes  dislikes
# 0      2564903.0   96321.0    7972.0
# 1      6109402.0  151250.0   11508.0
# 2      5315471.0  187303.0    7278.0
# 3       913268.0   16729.0    1386.0
# 4      2819118.0  153395.0    2416.0
# ...          ...       ...       ...
# 40761   812832.0    7701.0     320.0
# 40762   864189.0   18811.0     399.0
# 40764   540149.0   14206.0     693.0
# 40766   296295.0    8157.0     294.0
# 40949        NaN       NaN       NaN
#
# [6464 rows x 5 columns]

# %% [markdown]
# ## RIGHT JOIN
#
# ```SQL
# SELECT column_name(s)
# FROM table1
# RIGHT JOIN table2
# ON table1.column_name = table2.column_name;
# ```

# %%
df_titles.join(df_stats.set_index('video_id'), on='video_id', how='right')
# Out:
#           video_id                                              title  \
# 39169  -0CMnp02rNY  Mindy Kaling's Daughter Had the Perfect Reacti...
# 15457  -0NYY8cqdiQ  Megan Mullally Didn't Notice the Interesting P...
# 31553  -1Hm41N0dUs  Cast of Avengers: Infinity War Draws Their Cha...
# 3019   -1yT-K3c6YI  YOUTUBER QUIZ + TRUTH OR DARE W/ THE MERRELL T...
# 90     -2RVw2_QyxQ                     2017 Champions Showdown: Day 3
# ...            ...                                                ...
# 26002  zwEn-ambXLw  This Is Me - Cover by Shoshana Bean Featuring ...
# 246    zxUwbflE1SY  100 People Hold Their Breath for as Long as Th...
# 32150  zxwfDlhJIpw                 kanye west / charlamagne interview
# 144    zy0b9e40tK8             Dark | Official Trailer [HD] | Netflix
# 16360  zzQsGL_F9_c                     Budweiser | Beer Country | :60
#
#            views     likes  dislikes
# 39169   800359.0    9773.0     332.0
# 15457   563746.0    4429.0      54.0
# 31553  2058516.0   41248.0     580.0
# 3019    231341.0    7734.0     212.0
# 90       71089.0     460.0      27.0
# ...          ...       ...       ...
# 26002   241668.0    8478.0     144.0
# 246     225280.0    5770.0     150.0
# 32150  8442986.0  166520.0   19462.0
# 144     378750.0    5642.0     146.0
# 16360   199041.0    1415.0     121.0
#
# [6464 rows x 5 columns]
